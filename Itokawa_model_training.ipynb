# %% [markdown]
# # Ensemble model training for Itokawa and models
#
# This code trains ensemble models using reflectance spectra data as input (x) from the "Data" folder. The corresponding calculated exposure times (y) are provided in the "data_all_H_laser.xlsx" file.
#
# **Training Process:**
#
# - A total of 30 models are trained using the provided data.
# - Each model is saved in .joblib format for later use.
#
# **Output:**
# - The trained models are stored in the "Itokawa_Models" folder.

# %%
# !pip install tensorflow==2.17.1 keras==3.5.0
# Out:
# Requirement already satisfied: tensorflow==2.17.1 in /usr/local/lib/python3.11/dist-packages (2.17.1)
# Requirement already satisfied: keras==3.5.0 in /usr/local/lib/python3.11/dist-packages (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (1.69.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (2.17.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.17.1) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras==3.5.0) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras==3.5.0) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras==3.5.0) (0.13.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.17.1) (0.45.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.1) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.1) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras==3.5.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras==3.5.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras==3.5.0) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow==2.17.1) (3.0.2)

# %%
# !pip install scikeras==0.13.0
# Out:
# Collecting scikeras==0.13.0
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from scikeras==0.13.0) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from scikeras==0.13.0) (1.6.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras==0.13.0) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras==0.13.0) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras==0.13.0) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras==0.13.0) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras==0.13.0) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras==0.13.0) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras==0.13.0) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras==0.13.0) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras==0.13.0) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras==0.13.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras==0.13.0) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras>=3.2.0->scikeras==0.13.0) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras==0.13.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras==0.13.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras==0.13.0) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
# !pip install scikit-learn==1.5.2
# Out:
# Collecting scikit-learn==1.5.2
#   Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (3.5.0)
# Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 41.6 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.0
#     Uninstalling scikit-learn-1.6.0:
#       Successfully uninstalled scikit-learn-1.6.0
# Successfully installed scikit-learn-1.5.2

# %%
# !pip install numpy==1.26.4 joblib==1.4.2
# Out:
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: joblib==1.4.2 in /usr/local/lib/python3.11/dist-packages (1.4.2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import numpy as np
import pandas as pd
import pickle
import sklearn
import joblib
import os

# %%
from scipy.interpolate import interp1d
from scipy.ndimage import gaussian_filter1d
from keras.layers import Dense, Conv1D, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from tensorflow.keras.models import Sequential
from scikeras.wrappers import KerasRegressor
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import VotingRegressor,GradientBoostingRegressor,RandomForestRegressor, ExtraTreesRegressor
from sklearn.model_selection import StratifiedKFold
from sklearn.base import RegressorMixin, BaseEstimator
from sklearn.neighbors import KNeighborsRegressor
from scikeras.wrappers import KerasRegressor
from sklearn.metrics import r2_score
from sklearn.utils.validation import check_is_fitted
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-405652584.py in <cell line: 0>()
#      17 from keras.models import Sequential
#      18 from tensorflow.keras.models import Sequential
# ---> 19 from scikeras.wrappers import KerasRegressor
#      20 from sklearn.metrics import mean_squared_error
#      21 from sklearn.ensemble import VotingRegressor,GradientBoostingRegressor,RandomForestRegressor, ExtraTreesRegressor
#
# ModuleNotFoundError: No module named 'scikeras'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# This function, denoise_and_norm, processes spectral data with optional denoising and normalization. Reflectance spectra have been normalised at 1500 nm

# %%
def denoise_and_norm(data: np.ndarray, wavelength: np.ndarray, denoising: bool, normalising: bool, sigma_nm: float = 7.,
                     normalised_at_wvl: float = 1500.) -> np.ndarray:
    if np.ndim(data) == 1:
        data = np.reshape(data, (1, len(data)))

    if denoising:
        nm_to_px = 1. / (wavelength[1] - wavelength[0])  # conversion from nm to px
        correction = gaussian_filter1d(np.ones(len(wavelength)), sigma=sigma_nm * nm_to_px, mode="constant")
        data_denoised = gaussian_filter1d(data, sigma=sigma_nm * nm_to_px, mode="constant") / correction
    else:
        data_denoised = data

    # Normalised reflectance
    if normalising:
        fun = interp1d(wavelength, data_denoised, kind="cubic")  # v_final differs from v
        v_norm = np.reshape(fun(normalised_at_wvl), (len(data_denoised), 1))
    else:
        v_norm = 1.

    #return data_denoised / v_norm
    return (data_denoised / v_norm).flatten()

# %%
catalogue = pd.read_excel("/data_all_H_laser.xlsx",
                          index_col=None,
                          header=0,
                          na_values=["NA"],
                          engine="openpyxl")

sample_names = np.array(catalogue["Sample name"], dtype=str)
ET_1AU = np.array(catalogue["ET_1AU"], dtype=np.float32)
type = np.array(catalogue["type"], dtype=str)
irradiation = np.array(catalogue["Irradiation"], dtype=int)
log_ET_1AU = np.reshape(np.log10(np.array(catalogue["ET_1AU"], dtype=np.float32) + 1), (-1, 1))
group = np.array(catalogue["group"], dtype=int)

# %% [markdown]
# Interpolate reflectance spectra from 820 nm to 2080 nm, with 20-nm intervals
# and normalised at 550 nm using the function denoise_and_norm.

# %%
wavelengths_new = np.arange(820., 2080., 20.)

input_data = np.zeros((len(sample_names), len(wavelengths_new) + 1), dtype=np.float32)  # +1 for band slope

for i, sample_name in enumerate(sample_names):
    # Read the spectrum data from the CSV file
    spectra = pd.read_csv("/Data/" + sample_name + ".csv", header=1)

    wavelengths, spectra = spectra["W"].to_numpy() * 1000., spectra["R"].to_numpy()

    # Interpolate the spectra onto the new wavelengths using cubic interpolation (by ignoring the duplicate values)
    unique_wavelengths, unique_indices = np.unique(wavelengths, return_index=True)
    unique_spectra = spectra[unique_indices]

    interp_func = interp1d(unique_wavelengths, unique_spectra, kind="linear")
    interpolated_spectra = interp_func(wavelengths_new)

    # Call the denoise function
    denoised_normalized_data = denoise_and_norm(interpolated_spectra, wavelengths_new, denoising=True, normalising=True)

    input_data[i, :-1], input_data[i, -1] = denoised_normalized_data, irradiation[i]

    plt.plot(wavelengths_new/1000, denoised_normalized_data)

plt.xlabel("Wavelength (µm)", fontsize=12)
plt.ylabel("Reflectance", fontsize=12)
plt.tick_params(axis='x', labelsize=10)
plt.tick_params(axis='y', labelsize=10)
savefig_kwargs = {"bbox_inches": "tight",
                  "pad_inches": 0.05,
                  "dpi": 100}  # dpi only for jpg/png figures
plt.show()

# %%
print(input_data.shape)
# Out:
# (169, 64)

# %%
#CNN model
def create_cnn_model_1(input_shape,learning_rate=0.001):
    model = Sequential()
    model.add(Conv1D(filters=32, kernel_size=3, activation="relu", padding="same", input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Conv1D(filters=32, kernel_size=2, activation="relu", padding="same"))
    model.add(BatchNormalization())

    model.add(Flatten())
    model.add(Dense(1, activation="relu"))
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=["mean_absolute_error"])
    return model

# %% [markdown]
# This class extends KerasRegressor to integrate a CNN model for predicting continuous outputs.

# %%
#Custom Keras Regressor class for CNN-based regression tasks.

class CNNRegressor(KerasRegressor):
    _estimator_type = "regressor"

    def __init__(self, input_shape, learning_rate=0.001, epochs=10, batch_size=32, verbose=0, **kwargs):
        super().__init__(**kwargs)
        self.input_shape = input_shape
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.batch_size = batch_size
        self.verbose = verbose
        #super().__init__(build_fn=self._keras_build_fn, **kwargs)

    def _keras_build_fn(self):
        return create_cnn_model_1(self.input_shape, self.learning_rate)

# %%
output_folder = "/Itokawa_Models"
os.makedirs(output_folder, exist_ok=True)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for iteration in range(30):
    print(f"Starting iteration {iteration + 1}")

    iteration_train_indices, iteration_test_indices = [], []

    # Gather train indices for this iteration
    for train_index, _ in skf.split(input_data, group):
        iteration_train_indices.extend(train_index)

    # Use only training data for this iteration
    X_train = input_data[iteration_train_indices]
    y_train = log_ET_1AU[iteration_train_indices]

    # Create the ensemble model
    ensemble_model = VotingRegressor(
        estimators=[
            ('cnn', CNNRegressor(input_shape=(X_train.shape[1], 1), epochs=200, batch_size=32, verbose=1)),
            ('gbr', GradientBoostingRegressor(n_estimators=100, learning_rate=0.4, random_state=42)),
            ('knn', KNeighborsRegressor(n_neighbors=3)),
            ('etr', ExtraTreesRegressor(n_estimators=100, random_state=42)),
            ('rft', RandomForestRegressor(n_estimators=100, random_state=42))
        ],
        weights=[4, 4, 1, 5, 1],
        n_jobs=5
    )

    # Train the model
    ensemble_model.fit(X_train, y_train.ravel())

    #Save the trained model for this iteration in the 'models' folder
    model_filename = os.path.join(output_folder, f"En_Itikawa_{iteration + 1}.joblib")
    joblib.dump(ensemble_model, model_filename)
    print(f"Model for iteration {iteration + 1} saved to {model_filename}")

print("All models trained and saved.")
# Out:
# Starting iteration 1
# Model for iteration 1 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_1.joblib
# Starting iteration 2
# Model for iteration 2 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_2.joblib
# Starting iteration 3
# Model for iteration 3 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_3.joblib
# Starting iteration 4
# Model for iteration 4 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_4.joblib
# Starting iteration 5
# Model for iteration 5 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_5.joblib
# Starting iteration 6
# Model for iteration 6 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_6.joblib
# Starting iteration 7
# Model for iteration 7 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_7.joblib
# Starting iteration 8
# Model for iteration 8 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_8.joblib
# Starting iteration 9
# Model for iteration 9 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_9.joblib
# Starting iteration 10
# Model for iteration 10 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_10.joblib
# Starting iteration 11
# Model for iteration 11 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_11.joblib
# Starting iteration 12
# Model for iteration 12 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_12.joblib
# Starting iteration 13
# Model for iteration 13 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_13.joblib
# Starting iteration 14
# Model for iteration 14 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_14.joblib
# Starting iteration 15
# Model for iteration 15 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_15.joblib
# Starting iteration 16
# Model for iteration 16 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_16.joblib
# Starting iteration 17
# Model for iteration 17 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_17.joblib
# Starting iteration 18
# Model for iteration 18 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_18.joblib
# Starting iteration 19
# Model for iteration 19 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_19.joblib
# Starting iteration 20
# Model for iteration 20 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_20.joblib
# Starting iteration 21
# Model for iteration 21 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_21.joblib
# Starting iteration 22
# Model for iteration 22 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_22.joblib
# Starting iteration 23
# Model for iteration 23 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_23.joblib
# Starting iteration 24
# Model for iteration 24 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_24.joblib
# Starting iteration 25
# Model for iteration 25 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_25.joblib
# Starting iteration 26
# Model for iteration 26 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_26.joblib
# Starting iteration 27
# Model for iteration 27 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_27.joblib
# Starting iteration 28
# Model for iteration 28 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_28.joblib
# Starting iteration 29
# Model for iteration 29 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_29.joblib
# Starting iteration 30
# Model for iteration 30 saved to /content/drive/My Drive/Data_Ensemble/Itokawa_Eros_Models/En_Itikawa_30.joblib
# All models trained and saved.
